# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\octav\Downloads\1. Weather Data.csv")

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# # Question 1 Data Overview and Cleaning:

# %%
# 1.1

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.shape
# Out:
# (8784, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# # 1.1  key characteristics of the dataset

# %% [markdown]
# 1 The datat set shows that it has 8784 rows of data and also includes 8 columns from data set
#
#
# 2 The dataset has features such as Object, float,int, as numerial variables
#
# 3 the data types are float64(4), int64(2), object(2)

# %% [markdown]
# # 1.2 Identify and handle any missing or null values

# %% [markdown]
# 1 The dataset has no missing or null values as it is seen by using df.info() this specifies whether our data has null or mssing values and aslo the code below shows

# %%
df.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # 1.3 Check for and address any duplicate records.

# %% [markdown]
# 1 The dataset has no duplicate values using this code below it shows that no duplicates are present showing us that we do not need to address any duplicate records

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Question 2 Statistical Summary:

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# # 2.1 statistical summary of the dataset (mean, median, standard deviation, etc.) for numerical features.

# %% [markdown]
# The dataset contains 8,784 observations across six numerical features: Temperature (°C), Dew Point Temperature (°C), Relative Humidity (%), Wind Speed (km/h), Visibility (km), and Pressure (kPa). Below is a detailed statistical summary of these features:
#
# Temperature (°C):
#
# Mean: 8.80°C
# Median (50%): 9.30°C
# Standard Deviation: 11.69°C
# Min: -23.30°C
# Max: 33.00°C
# 25th Percentile: 0.10°C
# 75th Percentile: 18.80°C
# Dew Point Temperature (°C):
#
# Mean: 2.56°C
# Median (50%): 3.30°C
# Standard Deviation: 10.88°C
# Min: -28.50°C
# Max: 24.40°C
# 25th Percentile: -5.90°C
# 75th Percentile: 11.80°C
# Relative Humidity (%):
#
# Mean: 67.43%
# Median (50%): 68.00%
# Standard Deviation: 16.92%
# Min: 18.00%
# Max: 100.00%
# 25th Percentile: 56.00%
# 75th Percentile: 81.00%
# Wind Speed (km/h):
#
# Mean: 14.95 km/h
# Median (50%): 13.00 km/h
# Standard Deviation: 8.69 km/h
# Min: 0.00 km/h
# Max: 83.00 km/h
# 25th Percentile: 9.00 km/h
# 75th Percentile: 20.00 km/h
# Visibility (km):
#
# Mean: 27.66 km
# Median (50%): 25.00 km
# Standard Deviation: 12.62 km
# Min: 0.20 km
# Max: 48.30 km
# 25th Percentile: 24.10 km
# 75th Percentile: 25.00 km
# Pressure (kPa):
#
# Mean: 101.05 kPa
# Median (50%): 101.07 kPa
# Standard Deviation: 0.84 kPa
# Min: 97.52 kPa
# Max: 103.65 kPa
# 25th Percentile: 100.56 kPa
# 75th Percentile: 101.59 kPa

# %% [markdown]
# # 2.2 Identify and describe any significant outliers in the data.

# %% [markdown]
# Outlier Summary
#
# Wind Speed (km/h):
# The maximum recorded wind speed of 83.00 km/h is a significant outlier. It is considerably higher than the typical range of wind speeds, which is between 0.00 km/h and 36.50 km/h. This extreme value might represent an unusual weather event or could be an error in data recording.
#
# Visibility (km):
# Both the minimum value of 0.20 km and the maximum value of 48.30 km are notable outliers. The visibility typically ranges between 22.75 km and 26.35 km, making these values particularly unusual. The low visibility might indicate extreme weather conditions like fog, while the high visibility could correspond to exceptionally clear conditions.
#
# Pressure (kPa):
# The dataset shows pressure values as low as 97.52 kPa and as high as 103.65 kPa, both of which are significant outliers. These values fall outside the expected range of 99.02 kPa to 103.13 kPa, possibly indicating unusual atmospheric conditions or potential measurement errors.

# %% [markdown]
# # Question 3 Data Visualization:

# %% [markdown]
# # 3.1  Visualizations of Distribution of Key Weather Parameters

# %%
#1 Temperature
# 2 humidity
# 3 wind speed

# %% [markdown]
# # Temparature

# %%
plt.hist(df['Temp_C'])
plt.xlabel('Temperature')
plt.ylabel('Frequency');
plt.title('Temperature frequency distribution');

# %% [markdown]
# # Humididty

# %%
plt.hist(df['Rel Hum_%'])
plt.xlabel('Relative humidity')
plt.ylabel('Frequency');
plt.title('Relative humidity frequency distribution');

# %% [markdown]
# # Wind Speed

# %%
plt.hist(df['Wind Speed_km/h'])
plt.xlabel('Wind speed')
plt.ylabel('Frequency');
plt.title('Wind speed frequency distribution');

# %% [markdown]
# # 3.2 Plot time series graphs to visualize trends over time. Highlight any notable patterns or seasonal variations.

# %%
plt.figure(figsize=(15,10))

# Plot Temperature
plt.plot(df['Date/Time'], df['Temp_C'], color='gold', label='Temperature (°C)')

# Plot Humidity
plt.plot(df['Date/Time'], df['Rel Hum_%'], color='black', label='Relative Humidity (%)')

# Plot Wind Speed
plt.plot(df['Date/Time'], df['Wind Speed_km/h'], color='silver', label='Wind Speed (m/s)')

# Title and labels
plt.title('Temperature, Humidity, and Wind Speed over Time')
plt.xlabel('Date')
plt.ylabel('Values')

# Show legend
plt.legend()

# Adjust layout and display plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3.3 Create correlation matrices and heatmaps to identify relationships between different weather parameters

# %%
# lets change the time column first so we can answer questions

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df['Date/Time']=pd.to_datetime(df['Date/Time'])

# %%
df['Date/Time'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df
# Out:
#                Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  \
# 0    2012-01-01 00:00:00    -1.8              -3.9         86
# 1    2012-01-01 01:00:00    -1.8              -3.7         87
# 2    2012-01-01 02:00:00    -1.8              -3.4         89
# 3    2012-01-01 03:00:00    -1.5              -3.2         88
# 4    2012-01-01 04:00:00    -1.5              -3.3         88
# ...                  ...     ...               ...        ...
# 8779 2012-12-31 19:00:00     0.1              -2.7         81
# 8780 2012-12-31 20:00:00     0.2              -2.4         83
# 8781 2012-12-31 21:00:00    -0.5              -1.5         93
# 8782 2012-12-31 22:00:00    -0.2              -1.8         89
# 8783 2012-12-31 23:00:00     0.0              -2.1         86
#
#       Wind Speed_km/h  Visibility_km  Press_kPa               Weather
# 0                   4            8.0     101.24                   Fog
# 1                   4            8.0     101.24                   Fog
# ...

# %% [markdown]
# # Correlation

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv(r"C:\Users\octav\Downloads\1. Weather Data.csv")

# Select only numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the Spearman correlation matrix and round to 2 decimal places
correlation_matrix = numerical_df.corr(method='pearson').round(2)

# Style the correlation matrix with a uniform green background color
styled_matrix = correlation_matrix.style.background_gradient(axis=None, cmap='Greens')

# Display the styled correlation matrix
styled_matrix
# Out:
# <style type="text/css">
# #T_2be7e_row0_col0, #T_2be7e_row1_col1, #T_2be7e_row2_col2, #T_2be7e_row3_col3, #T_2be7e_row4_col4, #T_2be7e_row5_col5 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2be7e_row0_col1, #T_2be7e_row1_col0 {
#   background-color: #005120;
#   color: #f1f1f1;
# }
# #T_2be7e_row0_col2, #T_2be7e_row2_col0 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2be7e_row0_col3, #T_2be7e_row3_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_2be7e_row0_col4, #T_2be7e_row4_col0 {
#   background-color: #5eb96b;
#   color: #f1f1f1;
# }
# #T_2be7e_row0_col5, #T_2be7e_row5_col0 {
#   background-color: #caeac3;
#   color: #000000;
# }
# #T_2be7e_row1_col2, #T_2be7e_row2_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_2be7e_row1_col3, #T_2be7e_row3_col1 {
#   background-color: #b0dfaa;
#   color: #000000;
# }
# #T_2be7e_row1_col4, #T_2be7e_row4_col1 {
#   background-color: #92d28f;
#   color: #000000;
# }
# ...

# %%
# the darker the colour the higher the number / higher numbers get a darker float

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
df = pd.read_csv(r"C:\Users\octav\Downloads\1. Weather Data.csv")

# Select only numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the Spearman correlation matrix
correlation_matrix = numerical_df.corr(method='spearman').round(2)

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a heatmap with color gradient
sns.heatmap(correlation_matrix, 
            annot=True,                 # Annotate with correlation values
            cmap='Greens',              # Use green colormap
            mask=mask,                  # Mask the upper triangle
            vmin=-1, vmax=1,            # Set color range
            center=0,                   # Center the colormap at 0
            linewidths=0.5,            # Linewidths between cells
            linecolor='black',         # Line color between cells
            cbar_kws={'label': 'Correlation Value'})  # Colorbar label

# Add labels and title
plt.title('Spearman Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %% [markdown]
# # Heat Map

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv(r"C:\Users\octav\Downloads\1. Weather Data.csv")

# Select only numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr().round(2)

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a heatmap
sns.heatmap(correlation_matrix, 
            annot=True,              # Annotate with correlation values
            cmap='Greens',           # Use green colormap
            center=0,                # Center the colormap at 0
            vmin=-1, vmax=1,         # Set color scale range
            linewidths=0.5,         # Line width between cells
            linecolor='black')      # Line color between cells

# Add labels and title
plt.title('Heatmap of Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
df = pd.read_csv(r"C:\Users\octav\Downloads\1. Weather Data.csv")

# Select only numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr().round(2)

# Create a figure with a size of 8x8
plt.figure(figsize=(8, 8))

# Create a custom colormap
cmap = sns.diverging_palette(220, 20, as_cmap=True)

# Create a heatmap with custom colormap
sns.heatmap(correlation_matrix, 
            annot=True,              # Annotate with correlation values
            cmap=cmap,               # Use custom colormap
            center=0,                # Center the colormap at 0
            vmin=-1, vmax=1,         # Set color scale range
            linewidths=0.5,         # Line width between cells
            linecolor='black')      # Line color between cells

# Add labels and title
plt.title('Customized Heatmap of Correlation Matrix')  # Plot title

# Display the plot
plt.tight_layout()  # Adjust layout to fit labels
plt.show()

# %%
# Any one works best from the two

# %% [markdown]
# #  Question 4 Weather Patterns and Trends:

# %% [markdown]
# 4.1 Analyze and describe any trends or patterns you observe in the data. For instance, how do temperature and humidity vary across different seasons or months?

# %% [markdown]
# Patterns and Examples in the Information: Variations in temperature: Month to month Patterns: January and February are the coldest months, with normal temperatures of roughly - 7.37°C and - 4.23°C, individually. July is the hottest month, with a typical temperature of around 22.79°C. Temperatures begin to rise in March, reach their highest point in July, and then begin to fall in September. Occasional Patterns: Winter (December through February): The temperature hovers around -4.98°C on average. Summer: From June to August, the average temperature is 21.75 degrees Celsius. The seasons of spring (March through May) and autumn (September through November) have moderate temperatures, ranging from 8.81°C to 9.47°C on average. Stickiness Varieties: Month to month Patterns: The most elevated stickiness levels are seen in December and October, with normal moistness of 81.30% and 75.73%, separately. April experiences the lowest humidity, at an average of 56.15 percent. Trends in the Season: Winter has the most elevated mugginess, averaging 72.97%. Spring has the least dampness, averaging 60.98%. The average levels of humidity in the summer and autumn are moderate, at 63.57% and 72.33%, respectively. These perceptions demonstrate an unmistakable occasional example where temperatures top in the mid year and drop in the colder time of year, while moistness is by and large higher in the colder months.

# %% [markdown]
# 4.2 Investigate any anomalies or unusual patterns in the data. What might be the reasons for these anomalies?

# %% [markdown]
# Unusual patterns and anomalies: Anomalies of Temperature: On January 3, 2012, temperatures dropped as low as -17.3 °C, which was extremely low. On August 26, 2012, extremely high temperatures prevailed, reaching up to 30.4°C. Dampness Abnormalities: Very high stickiness levels, coming to close to 100% or even 100 percent, were noticed on various occasions, especially on Walk 14, 2012, and December 2, 2012. Potential Purposes behind These Oddities: Temperature Decreases in January: The very low temperatures in January could be because of a cool spell or an icy front, which are normal in winter, prompting unexpected decreases in temperature. Temperature Spikes in August: The high temperatures in August may be expected to a heatwave, which frequently happens in the late spring, bringing about strangely high temperatures. High Stickiness Levels: The very high dampness readings could be related with atmospheric conditions like haze, shower, or times of weighty precipitation, prompting immersion in the air. These oddities are steady with common weather conditions, yet their limit might warrant further examination concerning explicit climate occasions or nearby circumstances at those times.

# %% [markdown]
# # Question  5 Insights and Conclusions:

# %% [markdown]
# 5.1 Summarize the key insights you have gained from your EDA. What are the most interesting or surprising findings?

# %% [markdown]
# The Exploratory Data Analysis's (EDA) Most Important Findings: Temperature Changes Throughout the Season: Cold weather months (December to February) are the coldest, with normal temperatures around - 5°C, while Late spring months (June to August) are the hottest, with normal temperatures coming to up to 22°C. The temperature designs show a reasonable occasional cycle, with continuous warming from winter to summer and cooling from summer to winter. Stickiness Examples: Winter and Harvest time have higher normal mugginess levels, with tops in December and October. Spring has the most reduced typical moistness, recommending drier circumstances during these months. Oddities in Temperature and Mugginess: The beginning of January saw temperatures that were unusually low, reaching as low as -17.3 °C, and the end of August saw extreme heat, reaching 30.4 °C. Several times, extremely high humidity levels, close to 100%, were recorded, probably in connection with fog or precipitation. Findings That Are Curious or Surprising: The sharp differences in temperature limits around the same time feature the potential for critical occasional shifts, perhaps impacted by nearby climatic occasions. The reliably high moistness readings in winter and pre-winter propose a penchant for hazy or blustery circumstances during these periods, which might influence perceivability and travel.

# %% [markdown]
# 5.2 How can these insights be useful for weather prediction or other practical applications?

# %% [markdown]
# Commonsense Uses of the Experiences: Climate Expectation: Occasional Estimating: Understanding the reasonable occasional temperature cycles and dampness examples can work on the exactness of occasional weather conditions gauges. For instance, anticipating colder temperatures and higher stickiness in winter can help in planning for snow or ice occasions. Anomaly Detection: Models that predict similar anomalies can be made by identifying extremes in temperature and humidity. It is possible to issue early warnings for heat waves or cold snaps, minimizing the impact on infrastructure, agriculture, and health. Agriculture: Crop Arranging: Ranchers can utilize the experiences on temperature and mugginess examples to design planting and gathering plans. For instance, anticipating summer heat can guide the selection of heat-resistant crops, while knowing that spring is typically drier can assist in determining the need for irrigation. Ice Insurance: The forecast of chilly spells can assist ranchers with going to defensive lengths against ice, for example, utilizing ice covers or warmers to safeguard crops. Public Security and Foundation: Outrageous Climate Readiness: Specialists can utilize the bits of knowledge to plan for outrageous climate occasions. For example, preparing for heat waves in the summer and making sure there are enough heating resources in the winter can lower the risks for people who are most at risk. Maintenance of Infrastructure: High humidity, especially in the fall and winter, can cause buildings and roads to wear out more quickly. Convenient support timetables can be changed in light of these experiences to drag out the existence of framework. Logistics and transport: Perceivability and Wellbeing: The high dampness levels in winter and pre-winter, related with hazy circumstances, can influence perceivability on streets and air terminals. Increasing the frequency of weather-related alerts or adjusting speed limits can both increase safety by knowing when these conditions are likely to occur. Production network The executives: Expecting outrageous climate occasions can help in arranging coordinated factors and supply chains, guaranteeing that conveyances are made before conditions weaken or changing courses to keep away from impacted regions.

# %% [markdown]
# # Question 6
# # Suggest areas for further analysis or additional data that might be useful to explore.

# %% [markdown]
# Regions for Additional Investigation: Long haul Environment Patterns: Impact of Climate Change: Trends in temperature and humidity over multiple years may reveal long-term climate changes. This could incorporate warming patterns, changes in occasional examples, or expanded recurrence of outrageous climate occasions. Seasonal Shifts: Understanding how climate change is affecting local weather patterns can be gained by determining whether seasonal intensity or timing shifts over time. Relationship with Outer Elements: Precipitation Information: Adding precipitation information would assist with investigating the connection between temperature, mugginess, and precipitation. This might make it easier to see how these variables interact with one another and affect weather patterns. Wind Examples: Examining wind speed and bearing close by temperature and stickiness could assist with understanding how climate frameworks travel through the area, possibly prompting more exact climate forecasts. Outrageous Climate Occasions: Recurrence and Effect: Exploring the recurrence, length, and effect of outrageous climate occasions (e.g., heatwaves, chilly fronts, storms) would be important for risk evaluation and the board. Early warning systems could be improved by gaining an understanding of the conditions that led to these events. Provincial Examinations: Contrasting the information and nearby districts could uncover whether certain abnormalities or examples are restricted or part of more extensive territorial patterns.
#
# Variations hourly and daily: Diurnal Cycles: Breaking down day-to-day designs, for example, how temperature and mugginess change in the span of a day, could give experiences into the best times for outside exercises, energy use, and other time-delicate choices. Extreme Hours: It might be possible to improve short-term weather forecasting by determining which parts of the day are more susceptible to extreme conditions. Effects on Human Behavior: Health Implications: Public health planning and interventions could benefit from linking weather data to health records, such as the prevalence of heat-related illnesses or respiratory issues during high-humidity periods.
#
# Energy Utilization: Investigating the connection between weather conditions and energy use (e.g., warming and cooling interest) could help with enhancing energy assets and framework. Extra Information to Investigate: Sun-Powered Radiation: Remembering information on sun-based radiation could assist with dissecting its effect on temperature changes and energy utilization designs, particularly in anticipating heat waves. Air Quality: Assessing how weather conditions affect pollution and public health could benefit from including data on air quality, such as levels of pollutants or particulate matter. Geological Information: Consolidating topographical highlights, for example, rise or closeness to water bodies, could make sense of neighborhood varieties in weather conditions and give a more nuanced examination. Socioeconomic Data: Understanding the broader effects of weather on society and the economy could be made easier by connecting weather data with socioeconomic factors like population density, urbanization, or economic activities.
